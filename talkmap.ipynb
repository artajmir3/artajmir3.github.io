# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.2.0-py3-none-any.whl (10 kB)
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Collecting PyYAML
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Collecting pygithub
#   Downloading pygithub-2.9.1-py3-none-any.whl (449 kB)
#      ---------------------------------------- 0.0/449.7 kB ? eta -:--:--
#      ----- --------------------------------- 61.4/449.7 kB 1.7 MB/s eta 0:00:01
#      -------------- ----------------------- 174.1/449.7 kB 1.7 MB/s eta 0:00:01
#      ----------------- -------------------- 204.8/449.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------  440.3/449.7 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 449.7/449.7 kB 2.2 MB/s eta 0:00:00
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#      -------------------------------------- 125.4/125.4 kB 3.7 MB/s eta 0:00:00
# Collecting retrying
#   Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ---------------------------------------- 40.7/40.7 kB ? eta 0:00:00
# Collecting pynacl>=1.4.0
#   Downloading pynacl-1.6.2-cp38-abi3-win_amd64.whl (239 kB)
#      ---------------------------------------- 0.0/239.8 kB ? eta -:--:--
#      ------------------------------------- 239.8/239.8 kB 15.3 MB/s eta 0:00:00
# Collecting urllib3>=1.26.0
#   Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#      ---------------------------------------- 0.0/131.1 kB ? eta -:--:--
#      -------------------------------------- 131.1/131.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\artaj\data\artajmir3-github\artajmir3.github.io\.venv\lib\site-packages (from pygithub->getorg) (4.15.0)
# Collecting requests>=2.14.0
#   Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#      ---------------------------------------- 0.0/73.1 kB ? eta -:--:--
#      ---------------------------------------- 73.1/73.1 kB 3.9 MB/s eta 0:00:00
# Collecting pyjwt[crypto]>=2.4.0
#   Downloading pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Collecting cryptography>=3.4.0
#   Downloading cryptography-48.0.0-cp39-abi3-win_amd64.whl (3.8 MB)
#      ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#      ----- ---------------------------------- 0.5/3.8 MB 16.2 MB/s eta 0:00:01
#      --------------- ------------------------ 1.4/3.8 MB 18.2 MB/s eta 0:00:01
#      ------------------ --------------------- 1.8/3.8 MB 14.3 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 24.0 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 9.0 MB/s eta 0:00:00
# Collecting cffi>=2.0.0
#   Using cached cffi-2.0.0-cp310-cp310-win_amd64.whl (182 kB)
# Collecting certifi>=2023.5.7
#   Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
#      ---------------------------------------- 0.0/135.7 kB ? eta -:--:--
#      -------------------------------------- 135.7/135.7 kB 3.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.15-py3-none-any.whl (72 kB)
#      ---------------------------------------- 0.0/72.3 kB ? eta -:--:--
#      ---------------------------------------- 72.3/72.3 kB 2.0 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl (159 kB)
#      ---------------------------------------- 0.0/159.2 kB ? eta -:--:--
#      -------------------------------------- 159.2/159.2 kB 9.3 MB/s eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: urllib3, retrying, PyYAML, pyjwt, pycparser, idna, geographiclib, charset_normalizer, certifi, requests, python-frontmatter, geopy, cffi, pynacl, cryptography, pygithub, getorg
# Successfully installed PyYAML-6.0.3 certifi-2026.4.22 cffi-2.0.0 charset_normalizer-3.4.7 cryptography-48.0.0 geographiclib-2.1 geopy-2.4.1 getorg-0.3.1 idna-3.15 pycparser-3.0 pygithub-2.9.1 pyjwt-2.12.1 pynacl-1.6.2 python-frontmatter-1.2.0 requests-2.34.2 retrying-1.4.2 urllib3-2.7.0
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
